# %%
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("dataset.csv")

# %%
dataset["Price"]
# Out:
# 0       18349.70
# 1       18028.20
# 2       18157.00
# 3       18202.80
# 4       18117.15
#           ...
# 4049     3142.00
# 4050     3075.85
# 4051     3156.40
# 4052     3197.10
# 4053     3138.65
# Name: Price, Length: 4054, dtype: float64

# %%
target = dataset["Price"]

# %%
data = dataset.drop("Price",axis=1)

# %%
data
# Out:
#              Date      Open     High       Low     Volume Change(%)
# 0     11 Nov 2022  18272.35  18362.3  18259.35  378469072     1.78%
# 1     10 Nov 2022  18044.35  18103.1  17969.40  256451785    -0.71%
# 2     09 Nov 2022  18288.25  18296.4  18117.50  307155149    -0.25%
# 3     07 Nov 2022  18211.75  18255.5  18064.75  314758398     0.47%
# 4     04 Nov 2022  18053.40  18135.1  18017.15  267941526     0.36%
# ...           ...       ...      ...       ...        ...       ...
# 4049  10 Jul 2006   3077.10   3147.7   3064.10   65284275     2.15%
# 4050  07 Jul 2006   3157.95   3193.1   3056.30   90060282    -2.55%
# 4051  06 Jul 2006   3197.50   3197.5   3138.40   74893378    -1.27%
# 4052  05 Jul 2006   3136.95   3201.2   3121.80   90369711     1.86%
# 4053  04 Jul 2006   3151.05   3177.4   3130.30   66422150    -0.39%
#
# [4054 rows x 6 columns]

# %%
data = data.drop("Change(%)",axis=1)

# %%
data = data.drop("Date",axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(data,target,test_size=0.2,random_state=4)

# %%
x_train2 = x_train.to_numpy()
x_test2 = x_test.to_numpy()
y_train2 = y_train.to_numpy()
y_test2 = y_test.to_numpy()

# %%
x_train3 = x_train2.reshape(x_train2.shape[0],x_train2.shape[1],1)
x_test3 = x_test2.reshape(x_test2.shape[0],x_test2.shape[1],1)
y_train3 = y_train2.reshape(y_train2.shape[0],1,1)
y_test3 = y_test2.reshape(y_test2.shape[0],1,1)

# %%
y_test2.shape
# Out:
# (811,)

# %%
from keras.layers import Dropout
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(4,1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error",optimizer="adam", metrics=["mean_squared_error"])

# %%
model.summary()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_60 (LSTM)               (None, 4, 50)             10400
# _________________________________________________________________
# lstm_61 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dense_21 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 26
# ...
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train3,y_train3,validation_data=(x_test3,y_test3),epochs=60,batch_size=1,verbose=1)
# Out:
# Epoch 1/60
# 3243/3243 [==============================] - 10s 3ms/step - loss: 15279111.0000 - mean_squared_error: 15279111.0000 - val_loss: 15372642.0000 - val_mean_squared_error: 15372642.0000
# Epoch 2/60
# 1548/3243 [=============>................] - ETA: 3s - loss: 15446852.0000 - mean_squared_error: 15446852.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\MYTHRE~1\AppData\Local\Temp/ipykernel_8516/2459029606.py in <module>
# ----> 1 model.fit(x_train3,y_train3,validation_data=(x_test3,y_test3),epochs=60,batch_size=1,verbose=1)
#
# ...

# %%
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 4, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 4, 1), dtype=tf.float32, name='lstm_60_input'), name='lstm_60_input', description="created by layer 'lstm_60_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# array([[5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
#        [5833.4785],
# ...
